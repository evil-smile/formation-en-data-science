# %% [markdown]
# # <span style='color:red'>matplolib: la bibliotheque la plus utiliser en science des donnees</span>

# %% [markdown]
# ![matplotlib_logo.png](attachment:matplotlib_logo.png)

# %%
# importation des bibliotheques 
import numpy as np
import matplotlib.pyplot as plt

# %%
# courbe d'une fonction
x = np.linspace(1,10, 200)
y = x**2

plt.plot(x, y, label='courbe de f(x)=x**2')
plt.xlabel('x')
plt.ylabel('y')
plt.title('courbe de x et y')
plt.legend()
plt.show()

# %%
# trace de deux fonction 
x = np.linspace(0, 20, 20)
y1 = x ** 2
y2 =  2 * x

plt.figure()
plt.plot(x, y1, 'g', label="fonction x²")
plt.plot(x, y2, 'r', label="fonction 2x")

plt.xlabel('axe x')
plt.ylabel('axe y')
plt.title('Graphique montrant deux fonctions')
plt.legend()
plt.grid()

plt.show()

# %%
# les diagrammes circulaire
nb_utilisateurs = np.array([2.9, 2.3, 2, 1.4]) # En milliard d'utilisateurs
reseaux_sociaux = [
    "Facebook",
    "YouTube",
    "WhatsApp",
    "Instagram"
]

plt.title("Nombre d'utilisateurs des différents réseaux sociaux")
plt.pie(nb_utilisateurs, labels=reseaux_sociaux)
plt.show()

# %%
# le diagramme en baton
nb_utilisateurs = np.array([2.9, 2.3, 2, 1.4])
reseaux_sociaux = [
    "Facebook",
    "YouTube",
    "WhatsApp",
    "Instagram",
]

plt.bar(reseaux_sociaux, nb_utilisateurs)
plt.show()

# %%
# l'histogramme
x = np.random.binomial(n=20, p=0.2, size=1000) # Génère 1000 nombres selon une loi binomiale 
plt.hist(x)
plt.show()

# %%
# importation du dataset iris
from sklearn.datasets import load_iris

data = load_iris()
x = data.data
y = data.target
x
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
# les nuages de points

plt.scatter(x[:,0], x[:,1], lw=3)
plt.xlabel('x')
plt.ylabel('y')
plt.title('nuage de points')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# representation de plusieurs de nuage de points dans un meme graph
plt.figure(figsize=(10, 7))
plt.scatter(x[:, 0], x[:, 1], label='nuage de point 1')
plt.scatter(x[:, 2], x[:, 3], label='nuage de point 2')
plt.scatter(x[:, 3], x[:, 1], label='nuage de point 1')
plt.xlabel('x')
plt.ylabel('y')
plt.title(' representation de plusieurs de nuage de points')
plt.legend()
plt.show()

# %%
# representation de plusieurs courbes dans les graph distincts

plt.figure(figsize=(15, 15))

plt.subplot(4, 2, 1)
plt.scatter(x[:, 0], x[:, 1], label='nuage de point 1', c='r')
plt.legend()

plt.subplot(4, 2, 2)
plt.scatter(x[:, 2], x[:, 3], label='nuage de point 2', c='g')
plt.legend()

plt.subplot(4, 2, 3)
plt.scatter(x[:, 3], x[:, 1], label='nuage de point 3', c='b')
plt.legend()
plt.show()

# %%
# traitement d'image
import pandas as pd 
d = plt.imread('./image/jalil.jpg')
image = np.array(d)
plt.imshow(image)
plt.grid(visible=False)

# %%
# les dimensions de l'image
d.shape
# Out:
# (720, 1080, 3)

# %%
d
# Out:
# array([[[ 96,  87,  90],
#         [ 96,  87,  90],
#         [ 96,  87,  88],
#         ...,
#         [ 27,  26,  22],
#         [ 28,  27,  23],
#         [ 28,  27,  23]],
#
#        [[ 96,  87,  88],
#         [ 96,  87,  88],
#         [ 96,  88,  86],
#         ...,
#         [ 28,  27,  22],
#         [ 29,  28,  23],
#         [ 29,  28,  23]],
#
#        [[ 98,  88,  86],
#         [ 98,  88,  86],
#         [ 98,  89,  84],
#         ...,
#         [ 30,  29,  24],
#         [ 31,  30,  25],
#         [ 31,  30,  25]],
#
#        ...,
#
#        [[228, 221, 205],
#         [228, 221, 205],
#         [228, 221, 205],
#         ...,
#         [115,  85,  47],
#         [108,  78,  40],
#         [103,  73,  35]],
#
#        [[228, 221, 205],
#         [228, 221, 205],
#         [228, 221, 205],
#         ...,
#         [113,  83,  45],
#         [105,  75,  37],
#         [ 99,  69,  31]],
#
#        [[228, 221, 205],
#         [228, 221, 205],
#         [228, 221, 205],
# ...

# %%
#from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib

fig = plt.figure()
ax = fig.gca(projection='3d')

# creation des 
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Plot the surface with face colors taken from the array we made.
surf = ax.plot_surface(X, Y, Z, linewidth=0)

plt.show()
# Out:
# Using matplotlib backend: <object object at 0x0000016233C8A6A0>
# C:\Users\evil smile\AppData\Local\Temp\ipykernel_10776\1800710462.py:8: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')
