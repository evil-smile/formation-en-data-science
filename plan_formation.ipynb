# %% [markdown]
# # <span style='color:red'>FORMATION SUR LES BIBLIOTHEQUES DU LANGAGE PROGRAMMATION LES PLUS UTILISES EN SCIENCE DES DONNEES</span>

# %% [markdown]
# <vide>

# %% [markdown]
# ![data_science.png](attachment:data_science.png)

# %% [markdown]
# ### <span style='color:green'>Pourquoi se lancer dans l'apprentissage de l'intelligence artificielle ?🤷‍♂️</span>
#
#  *D'apres le magasine  [cairn infos](https://www.cairn.info/revue-say-2021-3-page-144.html), la progression du marché de l’intelligence artificielle (IA) est exponentielle. En 2021, il devrait peser plus de 327 milliards de dollars dans le monde. Et en 2030, la contribution à l’économie mondiale de l’IA pourrait atteindre 13 500 milliards de dollars, car plus de 70% des entreprises s’en serviront.*

# %% [markdown]
# # <span style='color:blue'>Plan de travail:</span>
#
# Comme indique le titre de cette formation, nous allons travailler sur les bibliotheques les plus populaire en science de donnees notemment pandas, numpy, seaborn, scikit-learnet maplotlib. Mais avant de commencer, je supporse que vous avez les bases en programmation python, dans le cas contraire vous pourvez allez vous former sur cette page [youtube](https://youtube.com/playlist?list=PLrSOXFDHBtfHg8fWBd7sKPxEmahwyVBkC).
#
# 1- la bibliotheque numpy
#
# 2- la bibliotheque matplotlib
#
# 3- la bibliotheque pandas
#
# 4- la bibliotheque seaborn
#
# 5- la bibliotheque scikit-learn
